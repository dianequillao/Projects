# %%
import pandas as pd
import numpy as np
from scipy.stats.mstats import mode
from sklearn.cross_validation import train_test_split
from sklearn import cross_validation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.linear_model import LinearRegression
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
% matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.utils import shuffle

import sklearn
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier


import statsmodels.api as sm
import statsmodels.formula.api as smf 

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score

from sklearn.linear_model import Lasso, Ridge, LassoCV, RidgeCV
from sklearn.pipeline import Pipeline
import imblearn.over_sampling

# %%
#!pip install imblearn

# %%
pwd
# Out:
# '/home/ubuntu/Notebooks/lending-club'

# %%
df = pd.read_csv('deleted_cols.csv')

# %%
df
# Out:
#         Unnamed: 0        id  member_id  loan_amnt  funded_amnt  \
# 0                0   1077501    1296599     5000.0       5000.0
# 1                1   1077430    1314167     2500.0       2500.0
# 2                2   1077175    1313524     2400.0       2400.0
# 3                3   1076863    1277178    10000.0      10000.0
# 4                4   1075358    1311748     3000.0       3000.0
# 5                5   1075269    1311441     5000.0       5000.0
# 6                6   1069639    1304742     7000.0       7000.0
# 7                7   1072053    1288686     3000.0       3000.0
# 8                8   1071795    1306957     5600.0       5600.0
# 9                9   1071570    1306721     5375.0       5375.0
# 10              10   1070078    1305201     6500.0       6500.0
# 11              11   1069908    1305008    12000.0      12000.0
# 12              12   1064687    1298717     9000.0       9000.0
# 13              13   1069866    1304956     3000.0       3000.0
# 14              14   1069057    1303503    10000.0      10000.0
# 15              15   1069759    1304871     1000.0       1000.0
# 16              16   1065775    1299699    10000.0      10000.0
# 17              17   1069971    1304884     3600.0       3600.0
# 18              18   1062474    1294539     6000.0       6000.0
# 19              19   1069742    1304855     9200.0       9200.0
# 20              20   1069740    1284848    20250.0      20250.0
# 21              21   1039153    1269083    21000.0      21000.0
# 22              22   1069710    1304821    10000.0      10000.0
# 23              23   1069700    1304810    10000.0      10000.0
# 24              24   1069559    1304634     6000.0       6000.0
# 25              25   1069697    1273773    15000.0      15000.0
# 26              26   1069800    1304679    15000.0      15000.0
# 27              27   1069657    1304764     5000.0       5000.0
# 28              28   1069799    1304678     4000.0       4000.0
# 29              29   1047704    1278806     8500.0       8500.0
# ...            ...       ...        ...        ...          ...
# 858019      887349  36691397   39434133    20000.0      20000.0
# 858020      887350  36500819   39232937    10300.0      10300.0
# 858021      887351  36743377   39486112     4200.0       4200.0
# 858022      887352  36231083   38942474    15000.0      15000.0
# 858023      887353  36371802   39103231    15000.0      15000.0
# 858024      887354  36250801   38962184     6000.0       6000.0
# 858025      887355  36331554   39042967    26950.0      26950.0
# 858026      887356  36460697   39182359    23000.0      23000.0
# 858027      887357  35773415   38468842    18700.0      18700.0
# 858028      887358  36440728   39152101    25000.0      25000.0
# 858029      887359  35591131   38288343    25000.0      25000.0
# 858030      887360  36361815   39093260    26500.0      26500.0
# 858031      887361  36201871   38913321    21000.0      21000.0
# 858032      887362  36381756   39013193     8000.0       8000.0
# 858033      887363  36231724   38943173    12000.0      12000.0
# 858034      887364  36231718   38943165    10775.0      10775.0
# 858035      887365  36381704   39013139     7000.0       7000.0
# 858036      887366  36241316   38952731     6225.0       6225.0
# 858037      887367  36301729   39023153    10000.0      10000.0
# 858038      887368  36250208   38961532    13150.0      13150.0
# 858039      887369  36421485   39142898     4000.0       4000.0
# 858040      887370  35094480   37777829     7500.0       7500.0
# 858041      887371  36260758   38972123    10850.0      10850.0
# 858042      887372  36330911   39042282    12000.0      12000.0
# 858043      887373  36221446   38932858    11575.0      11575.0
# 858044      887374  36371250   39102635    10000.0      10000.0
# 858045      887375  36441262   39152692    24000.0      24000.0
# 858046      887376  36271333   38982739    13000.0      13000.0
# 858047      887377  36490806   39222577    12000.0      12000.0
# 858048      887378  36271262   38982659    20000.0      20000.0
#
#         funded_amnt_inv  term  int_rate  installment grade ...   \
# 0           4975.000000    36     10.65       162.87     B ...
# 1           2500.000000    60     15.27        59.83     C ...
# 2           2400.000000    36     15.96        84.33     C ...
# 3          10000.000000    36     13.49       339.31     C ...
# 4           3000.000000    60     12.69        67.79     B ...
# 5           5000.000000    36      7.90       156.46     A ...
# 6           7000.000000    60     15.96       170.08     C ...
# 7           3000.000000    36     18.64       109.43     E ...
# 8           5600.000000    60     21.28       152.39     F ...
# 9           5350.000000    60     12.69       121.45     B ...
# 10          6500.000000    60     14.65       153.45     C ...
# 11         12000.000000    36     12.69       402.54     B ...
# 12          9000.000000    36     13.49       305.38     C ...
# 13          3000.000000    36      9.91        96.68     B ...
# 14         10000.000000    36     10.65       325.74     B ...
# 15          1000.000000    36     16.29        35.31     D ...
# 16         10000.000000    36     15.27       347.98     C ...
# 17          3600.000000    36      6.03       109.57     A ...
# 18          6000.000000    36     11.71       198.46     B ...
# 19          9200.000000    36      6.03       280.01     A ...
# 20         19142.161077    60     15.27       484.63     C ...
# 21         21000.000000    36     12.42       701.73     B ...
# 22         10000.000000    36     11.71       330.76     B ...
# 23         10000.000000    36     11.71       330.76     B ...
# 24          6000.000000    36     11.71       198.46     B ...
# 25         15000.000000    36      9.91       483.38     B ...
# 26          8725.000000    36     14.27       514.64     C ...
# 27          5000.000000    60     16.77       123.65     D ...
# 28          4000.000000    36     11.71       132.31     B ...
# 29          8500.000000    36     11.71       281.15     B ...
# ...                 ...   ...       ...          ...   ... ...
# 858019     20000.000000    36      6.99       617.46     A ...
# 858020     10300.000000    60     13.66       237.86     C ...
# 858021      4200.000000    36     15.99       147.64     D ...
# 858022     15000.000000    36     11.99       498.15     B ...
# 858023     15000.000000    60     11.44       329.44     B ...
# 858024      6000.000000    36     17.86       216.50     D ...
# 858025     26950.000000    36      8.19       846.88     A ...
# 858026     23000.000000    60     15.59       554.32     D ...
# 858027     18700.000000    60     17.86       473.44     D ...
# 858028     25000.000000    60     15.99       607.82     D ...
# 858029     25000.000000    60     15.59       602.52     D ...
# 858030     26500.000000    60      8.67       545.87     B ...
# 858031     21000.000000    36      6.03       639.15     A ...
# 858032      8000.000000    36      8.19       251.40     A ...
# 858033     12000.000000    36      9.49       384.34     B ...
# 858034     10775.000000    36      6.03       327.95     A ...
# 858035      7000.000000    36     14.31       240.30     C ...
# 858036      6225.000000    36     16.49       220.37     D ...
# 858037     10000.000000    36      6.49       306.45     A ...
# 858038     13150.000000    60     14.99       312.77     C ...
# 858039      4000.000000    36      8.67       126.59     B ...
# 858040      7500.000000    36      9.49       240.22     B ...
# 858041     10850.000000    36     19.24       399.04     E ...
# 858042     12000.000000    36     11.99       398.52     B ...
# 858043     11575.000000    36     15.59       404.61     D ...
# 858044     10000.000000    36     11.99       332.10     B ...
# 858045     24000.000000    36     11.99       797.03     B ...
# 858046     13000.000000    60     15.99       316.07     D ...
# 858047     12000.000000    60     19.99       317.86     E ...
# 858048     20000.000000    36     11.99       664.20     B ...
#
#        total_rec_late_fee recoveries collection_recovery_fee  last_pymnt_amnt  \
# 0                    0.00       0.00                  0.0000           171.62
# 1                    0.00     117.08                  1.1100           119.66
# 2                    0.00       0.00                  0.0000           649.91
# 3                   16.97       0.00                  0.0000           357.48
# 4                    0.00       0.00                  0.0000            67.79
# 5                    0.00       0.00                  0.0000           161.03
# 6                    0.00       0.00                  0.0000           170.08
# 7                    0.00       0.00                  0.0000           111.34
# 8                    0.00     189.06                  2.0900           152.39
# 9                    0.00     269.29                  2.5200           121.45
# 10                   0.00       0.00                  0.0000          1655.54
# 11                   0.00       0.00                  0.0000          6315.30
# 12                   0.00     444.30                  4.1600           305.38
# 13                   0.00       0.00                  0.0000           102.43
# 14                   0.00     645.10                  6.3145           325.74
# 15                   0.00       0.00                  0.0000            36.32
# 16                   0.00       0.00                  0.0000           370.46
# 17                   0.00       0.00                  0.0000           583.45
# 18                  15.00       0.00                  0.0000            16.98
# 19                   0.00       0.00                  0.0000          8061.10
# 20                   0.00       0.00                  0.0000          6024.09
# 21                   0.00       0.00                  0.0000           701.73
# 22                   0.00       0.00                  0.0000           349.21
# 23                   0.00       0.00                  0.0000          4942.63
# 24                   0.00     269.31                  2.5700           198.46
# 25                   0.00       0.00                  0.0000          2447.05
# 26                   0.00       0.00                  0.0000             0.00
# 27                   0.00     260.96                  2.3000           123.65
# 28                   0.00       0.00                  0.0000          2638.77
# 29                   0.00       0.00                  0.0000           581.59
# ...                   ...        ...                     ...              ...
# 858019               0.00       0.00                  0.0000           617.46
# 858020               0.00       0.00                  0.0000           237.86
# 858021               0.00       0.00                  0.0000           147.64
# 858022               0.00       0.00                  0.0000           498.15
# 858023               0.00       0.00                  0.0000           329.44
# 858024               0.00       0.00                  0.0000           216.50
# 858025               0.00       0.00                  0.0000           846.88
# 858026               0.00       0.00                  0.0000           554.32
# 858027               0.00       0.00                  0.0000           473.44
# 858028               0.00       0.00                  0.0000           607.82
# 858029               0.00       0.00                  0.0000           602.52
# 858030               0.00       0.00                  0.0000           545.87
# 858031               0.00       0.00                  0.0000           639.15
# 858032               0.00       0.00                  0.0000           251.40
# 858033               0.00       0.00                  0.0000           384.34
# 858034               0.00       0.00                  0.0000          9439.34
# 858035               0.00       0.00                  0.0000           240.30
# 858036               0.00       0.00                  0.0000          4858.17
# 858037               0.00       0.00                  0.0000           306.45
# 858038               0.00       0.00                  0.0000           312.77
# 858039               0.00       0.00                  0.0000          3655.51
# 858040               0.00       0.00                  0.0000           240.22
# 858041               0.00       0.00                  0.0000            25.00
# 858042               0.00       0.00                  0.0000           398.52
# 858043               0.00       0.00                  0.0000           404.61
# 858044               0.00       0.00                  0.0000           332.10
# 858045               0.00       0.00                  0.0000           797.03
# 858046               0.00       0.00                  0.0000           316.07
# 858047               0.00       0.00                  0.0000           317.86
# 858048               0.00       0.00                  0.0000           664.20
#
#        policy_code application_type MORTGAGE NONE OWN RENT
# 0              1.0       INDIVIDUAL        0    0   0    1
# 1              1.0       INDIVIDUAL        0    0   0    1
# 2              1.0       INDIVIDUAL        0    0   0    1
# 3              1.0       INDIVIDUAL        0    0   0    1
# 4              1.0       INDIVIDUAL        0    0   0    1
# 5              1.0       INDIVIDUAL        0    0   0    1
# 6              1.0       INDIVIDUAL        0    0   0    1
# 7              1.0       INDIVIDUAL        0    0   0    1
# 8              1.0       INDIVIDUAL        0    0   1    0
# 9              1.0       INDIVIDUAL        0    0   0    1
# 10             1.0       INDIVIDUAL        0    0   1    0
# 11             1.0       INDIVIDUAL        0    0   1    0
# 12             1.0       INDIVIDUAL        0    0   0    1
# 13             1.0       INDIVIDUAL        0    0   0    1
# 14             1.0       INDIVIDUAL        0    0   0    1
# 15             1.0       INDIVIDUAL        0    0   0    1
# 16             1.0       INDIVIDUAL        0    0   0    1
# 17             1.0       INDIVIDUAL        1    0   0    0
# 18             1.0       INDIVIDUAL        1    0   0    0
# 19             1.0       INDIVIDUAL        0    0   0    1
# 20             1.0       INDIVIDUAL        0    0   0    1
# 21             1.0       INDIVIDUAL        0    0   0    1
# 22             1.0       INDIVIDUAL        0    0   1    0
# 23             1.0       INDIVIDUAL        0    0   0    1
# 24             1.0       INDIVIDUAL        0    0   0    1
# 25             1.0       INDIVIDUAL        1    0   0    0
# 26             1.0       INDIVIDUAL        0    0   0    1
# 27             1.0       INDIVIDUAL        0    0   0    1
# 28             1.0       INDIVIDUAL        1    0   0    0
# 29             1.0       INDIVIDUAL        0    0   0    1
# ...            ...              ...      ...  ...  ..  ...
# 858019         1.0       INDIVIDUAL        1    0   0    0
# 858020         1.0       INDIVIDUAL        0    0   0    1
# 858021         1.0       INDIVIDUAL        1    0   0    0
# 858022         1.0       INDIVIDUAL        0    0   0    1
# 858023         1.0       INDIVIDUAL        0    0   0    1
# 858024         1.0       INDIVIDUAL        1    0   0    0
# 858025         1.0       INDIVIDUAL        0    0   0    1
# 858026         1.0       INDIVIDUAL        1    0   0    0
# 858027         1.0       INDIVIDUAL        0    0   0    1
# 858028         1.0       INDIVIDUAL        0    0   0    1
# 858029         1.0       INDIVIDUAL        0    0   1    0
# 858030         1.0       INDIVIDUAL        1    0   0    0
# 858031         1.0       INDIVIDUAL        1    0   0    0
# 858032         1.0       INDIVIDUAL        1    0   0    0
# 858033         1.0       INDIVIDUAL        0    0   0    1
# 858034         1.0       INDIVIDUAL        0    0   0    1
# 858035         1.0       INDIVIDUAL        0    0   0    1
# 858036         1.0       INDIVIDUAL        0    0   0    1
# 858037         1.0       INDIVIDUAL        0    0   0    1
# 858038         1.0       INDIVIDUAL        1    0   0    0
# 858039         1.0       INDIVIDUAL        1    0   0    0
# 858040         1.0       INDIVIDUAL        0    0   0    1
# 858041         1.0       INDIVIDUAL        0    0   1    0
# 858042         1.0       INDIVIDUAL        1    0   0    0
# 858043         1.0       INDIVIDUAL        0    0   0    1
# 858044         1.0       INDIVIDUAL        0    0   0    1
# 858045         1.0       INDIVIDUAL        1    0   0    0
# 858046         1.0       INDIVIDUAL        0    0   0    1
# 858047         1.0       INDIVIDUAL        0    0   0    1
# 858048         1.0       INDIVIDUAL        0    0   0    1
#
# [858049 rows x 46 columns]

# %%
#Delete Unnamed column
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
#Conver earliest_cr_line and issue_d to datetime

df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'])

df['issue_d'] = pd.to_datetime(df['issue_d'])

# %%
df.shape
# Out:
# (858049, 45)

# %%
#The list of columns
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'url', 'purpose', 'zip_code', 'addr_state',
#        'dti', 'earliest_cr_line', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt', 'policy_code',
#        'application_type', 'MORTGAGE', 'NONE', 'OWN', 'RENT'],
#       dtype='object')

# %% [markdown]
# To prepare the dataframe for analysis, I will shuffle the data and then use test_train_split.

# %%
#Shuffle dataframe
df = shuffle(df, random_state = 1)

# %%
df.head()
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 694270  51848807   55278581    20000.0      20000.0          20000.0    36
# 34973     442381     537306    20000.0      20000.0          19050.0    36
# 226795  37692106   40465191    28000.0      28000.0          28000.0    60
# 382048  16101417   18203903     6000.0       6000.0           6000.0    36
# 785277  42673919   45670681    12000.0      12000.0          12000.0    60
#
#         int_rate  installment grade sub_grade ...  total_rec_late_fee  \
# 694270      9.99       645.25     B        B3 ...                 0.0
# 34973      14.26       686.12     C        C5 ...                 0.0
# 226795     10.49       601.70     B        B3 ...                 0.0
# 382048     10.15       194.03     B        B2 ...                 0.0
# 785277     16.99       298.17     D        D3 ...                 0.0
#
#        recoveries  collection_recovery_fee last_pymnt_amnt policy_code  \
# 694270        0.0                      0.0          645.25         1.0
# 34973         0.0                      0.0        18372.64         1.0
# 226795        0.0                      0.0        24652.44         1.0
# 382048        0.0                      0.0         5315.97         1.0
# 785277        0.0                      0.0          298.17         1.0
#
#        application_type MORTGAGE NONE OWN RENT
# 694270       INDIVIDUAL        1    0   0    0
# 34973        INDIVIDUAL        1    0   0    0
# 226795       INDIVIDUAL        1    0   0    0
# 382048       INDIVIDUAL        0    0   1    0
# 785277       INDIVIDUAL        1    0   0    0
#
# [5 rows x 45 columns]

# %%
df.corr()
# Out:
#                                id  member_id  loan_amnt  funded_amnt  \
# id                       1.000000   0.999434   0.065409     0.067711
# member_id                0.999434   1.000000   0.066083     0.068426
# loan_amnt                0.065409   0.066083   1.000000     0.999242
# funded_amnt              0.067711   0.068426   0.999242     1.000000
# funded_amnt_inv          0.073203   0.074029   0.997052     0.997986
# term                     0.071534   0.071881   0.411089     0.410095
# int_rate                -0.144219  -0.143449   0.142521     0.142648
# installment              0.025890   0.026594   0.944925     0.945983
# annual_inc               0.034185   0.034360   0.335102     0.334864
# dti                      0.067231   0.067282   0.020637     0.021040
# open_acc                 0.089756   0.089872   0.199325     0.199819
# pub_rec                  0.080604   0.081292  -0.081850    -0.081501
# revol_bal                0.036908   0.036877   0.334046     0.333899
# revol_util              -0.052915  -0.052628   0.119596     0.120100
# total_acc                0.031752   0.031928   0.222494     0.222423
# out_prncp                0.563175   0.563608   0.639872     0.641850
# out_prncp_inv            0.563138   0.563570   0.639874     0.641852
# total_pymnt             -0.591728  -0.591200   0.479526     0.478181
# total_pymnt_inv         -0.587109  -0.586455   0.480519     0.479362
# total_rec_prncp         -0.551805  -0.551467   0.395880     0.394652
# total_rec_int           -0.455668  -0.454730   0.537553     0.536471
# total_rec_late_fee      -0.077732  -0.078209   0.024256     0.023848
# recoveries              -0.115011  -0.115091   0.074872     0.074411
# collection_recovery_fee -0.073086  -0.073076   0.053514     0.053273
# last_pymnt_amnt         -0.227535  -0.226971   0.233791     0.233331
# policy_code                   NaN        NaN        NaN          NaN
# MORTGAGE                -0.008937  -0.008355   0.192104     0.191909
# NONE                    -0.009703  -0.009846  -0.000544    -0.000533
# OWN                      0.038347   0.038362  -0.020734    -0.020544
# RENT                    -0.014025  -0.014626  -0.183427    -0.183344
#
#                          funded_amnt_inv      term  int_rate  installment  \
# id                              0.073203  0.071534 -0.144219     0.025890
# member_id                       0.074029  0.071881 -0.143449     0.026594
# loan_amnt                       0.997052  0.411089  0.142521     0.944925
# funded_amnt                     0.997986  0.410095  0.142648     0.945983
# funded_amnt_inv                 1.000000  0.410734  0.142663     0.943562
# term                            0.410734  1.000000  0.426874     0.143969
# int_rate                        0.142663  0.426874  1.000000     0.130125
# installment                     0.943562  0.143969  0.130125     1.000000
# annual_inc                      0.333811  0.058948 -0.073623     0.328567
# dti                             0.022139  0.050381  0.078458     0.014322
# open_acc                        0.200428  0.086311 -0.010605     0.184280
# pub_rec                        -0.080443 -0.024976  0.052585    -0.070815
# revol_bal                       0.332178  0.091291 -0.034732     0.317255
# revol_util                      0.120813  0.085743  0.271411     0.131864
# total_acc                       0.222646  0.101849 -0.039167     0.200343
# out_prncp                       0.644577  0.391421  0.033222     0.539902
# out_prncp_inv                   0.644588  0.391378  0.033078     0.539897
# total_pymnt                     0.473727  0.083788  0.173538     0.520626
# total_pymnt_inv                 0.478958  0.085443  0.174473     0.521453
# total_rec_prncp                 0.390288 -0.024006  0.059521     0.455517
# total_rec_int                   0.533935  0.383700  0.446444     0.502121
# total_rec_late_fee              0.020299  0.001105  0.050666     0.034251
# recoveries                      0.072472  0.058806  0.110417     0.076407
# collection_recovery_fee         0.050711  0.036891  0.073321     0.055744
# last_pymnt_amnt                 0.232100  0.074036  0.107251     0.243415
# policy_code                          NaN       NaN       NaN          NaN
# MORTGAGE                        0.191720  0.108982 -0.060560     0.159762
# NONE                           -0.000947 -0.002338  0.003117     0.000750
# OWN                            -0.020034 -0.014494  0.001961    -0.016923
# RENT                           -0.183454 -0.102371  0.060559    -0.152759
#
#                          annual_inc       dti    ...     total_rec_int  \
# id                         0.034185  0.067231    ...         -0.455668
# member_id                  0.034360  0.067282    ...         -0.454730
# loan_amnt                  0.335102  0.020637    ...          0.537553
# funded_amnt                0.334864  0.021040    ...          0.536471
# funded_amnt_inv            0.333811  0.022139    ...          0.533935
# term                       0.058948  0.050381    ...          0.383700
# int_rate                  -0.073623  0.078458    ...          0.446444
# installment                0.328567  0.014322    ...          0.502121
# annual_inc                 1.000000 -0.086619    ...          0.130747
# dti                       -0.086619  1.000000    ...          0.008852
# open_acc                   0.140187  0.142369    ...          0.062118
# pub_rec                   -0.008848 -0.022638    ...         -0.059796
# revol_bal                  0.298704  0.066563    ...          0.139338
# revol_util                 0.036882  0.086900    ...          0.183545
# total_acc                  0.189430  0.106610    ...          0.092260
# out_prncp                  0.211044  0.058572    ...          0.111882
# out_prncp_inv              0.211085  0.058536    ...          0.111896
# total_pymnt                0.163577 -0.040502    ...          0.679463
# total_pymnt_inv            0.163532 -0.039327    ...          0.678671
# total_rec_prncp            0.152552 -0.050835    ...          0.488911
# total_rec_int              0.130747  0.008852    ...          1.000000
# total_rec_late_fee         0.009986 -0.006830    ...          0.079667
# recoveries                 0.007827  0.001501    ...          0.069469
# collection_recovery_fee    0.006806  0.002421    ...          0.053249
# last_pymnt_amnt            0.092570 -0.028476    ...          0.138026
# policy_code                     NaN       NaN    ...               NaN
# MORTGAGE                   0.157110 -0.002926    ...          0.099933
# NONE                      -0.001289  0.000186    ...          0.006951
# OWN                       -0.031553  0.014932    ...         -0.033633
# RENT                      -0.141136 -0.006086    ...         -0.081652
#
#                          total_rec_late_fee  recoveries  \
# id                                -0.077732   -0.115011
# member_id                         -0.078209   -0.115091
# loan_amnt                          0.024256    0.074872
# funded_amnt                        0.023848    0.074411
# funded_amnt_inv                    0.020299    0.072472
# term                               0.001105    0.058806
# int_rate                           0.050666    0.110417
# installment                        0.034251    0.076407
# annual_inc                         0.009986    0.007827
# dti                               -0.006830    0.001501
# open_acc                          -0.010470    0.001854
# pub_rec                           -0.012007   -0.014533
# revol_bal                          0.001051    0.010867
# revol_util                         0.019304    0.029309
# total_acc                         -0.006281    0.009616
# out_prncp                         -0.048161   -0.111204
# out_prncp_inv                     -0.048164   -0.111204
# total_pymnt                        0.054199    0.037454
# total_pymnt_inv                    0.050771    0.036053
# total_rec_prncp                    0.033495   -0.039704
# total_rec_int                      0.079667    0.069469
# total_rec_late_fee                 1.000000    0.085526
# recoveries                         0.085526    1.000000
# collection_recovery_fee            0.079092    0.802460
# last_pymnt_amnt                   -0.010069   -0.038542
# policy_code                             NaN         NaN
# MORTGAGE                          -0.003850    0.004250
# NONE                              -0.000655    0.004393
# OWN                               -0.000655   -0.004611
# RENT                               0.004336   -0.001601
#
#                          collection_recovery_fee  last_pymnt_amnt  \
# id                                     -0.073086        -0.227535
# member_id                              -0.073076        -0.226971
# loan_amnt                               0.053514         0.233791
# funded_amnt                             0.053273         0.233331
# funded_amnt_inv                         0.050711         0.232100
# term                                    0.036891         0.074036
# int_rate                                0.073321         0.107251
# installment                             0.055744         0.243415
# annual_inc                              0.006806         0.092570
# dti                                     0.002421        -0.028476
# open_acc                                0.003498         0.029336
# pub_rec                                -0.008808        -0.034126
# revol_bal                               0.008275         0.059424
# revol_util                              0.019266        -0.000884
# total_acc                               0.010578         0.087951
# out_prncp                              -0.076697        -0.332674
# out_prncp_inv                          -0.076697        -0.332674
# total_pymnt                             0.035831         0.662147
# total_pymnt_inv                         0.033542         0.662730
# total_rec_prncp                        -0.024245         0.743878
# total_rec_int                           0.053249         0.138026
# total_rec_late_fee                      0.079092        -0.010069
# recoveries                              0.802460        -0.038542
# collection_recovery_fee                 1.000000        -0.026426
# last_pymnt_amnt                        -0.026426         1.000000
# policy_code                                  NaN              NaN
# MORTGAGE                                0.004966         0.070619
# NONE                                    0.004184         0.002145
# OWN                                    -0.002797        -0.014227
# RENT                                   -0.003431        -0.063453
#
#                          policy_code  MORTGAGE      NONE       OWN      RENT
# id                               NaN -0.008937 -0.009703  0.038347 -0.014025
# member_id                        NaN -0.008355 -0.009846  0.038362 -0.014626
# loan_amnt                        NaN  0.192104 -0.000544 -0.020734 -0.183427
# funded_amnt                      NaN  0.191909 -0.000533 -0.020544 -0.183344
# funded_amnt_inv                  NaN  0.191720 -0.000947 -0.020034 -0.183454
# term                             NaN  0.108982 -0.002338 -0.014494 -0.102371
# int_rate                         NaN -0.060560  0.003117  0.001961  0.060559
# installment                      NaN  0.159762  0.000750 -0.016923 -0.152759
# annual_inc                       NaN  0.157110 -0.001289 -0.031553 -0.141136
# dti                              NaN -0.002926  0.000186  0.014932 -0.006086
# open_acc                         NaN  0.125141 -0.000837 -0.005657 -0.124249
# pub_rec                          NaN -0.007887 -0.002449  0.004055  0.005622
# revol_bal                        NaN  0.152481 -0.000325  0.006232 -0.159375
# revol_util                       NaN  0.019940  0.001804 -0.043794  0.006223
# total_acc                        NaN  0.212131 -0.001469 -0.011227 -0.209623
# out_prncp                        NaN  0.111592 -0.006474  0.009155 -0.119335
# out_prncp_inv                    NaN  0.111601 -0.006473  0.009148 -0.119340
# total_pymnt                      NaN  0.111141  0.007558 -0.037227 -0.090915
# total_pymnt_inv                  NaN  0.111692  0.007311 -0.036793 -0.091736
# total_rec_prncp                  NaN  0.100263  0.006514 -0.033333 -0.082164
# total_rec_int                    NaN  0.099933  0.006951 -0.033633 -0.081652
# total_rec_late_fee               NaN -0.003850 -0.000655 -0.000655  0.004336
# recoveries                       NaN  0.004250  0.004393 -0.004611 -0.001601
# collection_recovery_fee          NaN  0.004966  0.004184 -0.002797 -0.003431
# last_pymnt_amnt                  NaN  0.070619  0.002145 -0.014227 -0.063453
# policy_code                      NaN       NaN       NaN       NaN       NaN
# MORTGAGE                         NaN  1.000000 -0.007341 -0.330850 -0.819377
# NONE                             NaN -0.007341  1.000000 -0.002416 -0.005984
# OWN                              NaN -0.330850 -0.002416  1.000000 -0.269696
# RENT                             NaN -0.819377 -0.005984 -0.269696  1.000000
#
# [30 rows x 30 columns]

# %%
#Correlation Heatmap

sns.heatmap(df.corr(), square=True, cmap='RdYlGn')

# %%
df.shape
# Out:
# (858049, 45)

# %%
pwd
# Out:
# '/home/ubuntu/Notebooks/lending-club'

# %% [markdown]
# #### Analyzing Target

# %%
df['loan_status'].value_counts()
# Out:
# Current    810913
# Default     47136
# Name: loan_status, dtype: int64

# %%
loans_df = df['loan_status']
loans_df.head()
# Out:
# 694270    Current
# 34973     Current
# 226795    Current
# 382048    Current
# 785277    Current
# Name: loan_status, dtype: object

# %%
ax = sns.countplot(loans_df)
ax.set(xlabel='Loan Status', ylabel='Count')
plt.title('Loan Statuses')
plt.show()

# %%
#Convert loan_status labels to 0 for Default and 1 for Current
df['loan_status'] = df['loan_status'].replace({'Current': 0, 'Default': 1})

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'url', 'purpose', 'zip_code', 'addr_state',
#        'dti', 'earliest_cr_line', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt', 'policy_code',
#        'application_type', 'MORTGAGE', 'NONE', 'OWN', 'RENT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                                  int64
# member_id                           int64
# loan_amnt                         float64
# funded_amnt                       float64
# funded_amnt_inv                   float64
# term                                int64
# int_rate                          float64
# installment                       float64
# grade                              object
# sub_grade                          object
# emp_length                         object
# home_ownership                     object
# annual_inc                        float64
# verification_status                object
# issue_d                    datetime64[ns]
# loan_status                         int64
# pymnt_plan                         object
# url                                object
# purpose                            object
# zip_code                           object
# addr_state                         object
# dti                               float64
# earliest_cr_line           datetime64[ns]
# open_acc                          float64
# pub_rec                           float64
# revol_bal                         float64
# revol_util                        float64
# total_acc                         float64
# initial_list_status                object
# out_prncp                         float64
# out_prncp_inv                     float64
# total_pymnt                       float64
# total_pymnt_inv                   float64
# total_rec_prncp                   float64
# total_rec_int                     float64
# total_rec_late_fee                float64
# recoveries                        float64
# collection_recovery_fee           float64
# last_pymnt_amnt                   float64
# policy_code                       float64
# application_type                   object
# MORTGAGE                            int64
# NONE                                int64
# OWN                                 int64
# RENT                                int64
# dtype: object

# %% [markdown]
# ### Define Variables - Using All Features that were relevant before the loan was issued

# %%
X = df[['member_id', 'int_rate', 'loan_amnt', 'annual_inc', 'dti',
       'revol_util', 'total_acc', 'term', 'pub_rec']]
y = df['loan_status']

# %%
sns.heatmap(X.corr(), square=True, cmap='RdYlGn').set_title('Heatmap of Features - After LASSO')
# Out:
# Text(0.5,1,'Heatmap of Features - After LASSO')

# %%
#Test_train_split
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.20, random_state=1)

# %%
std = StandardScaler()
std.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
#Apply the scaler to the train set
X_tr = std.transform(X_train)

#Apply the scaler to the test set
X_te = std.transform(X_test)

# %% [markdown]
# ## Logistic Regression Using Statsmodels

# %%
model = sm.Logit(y_train,X_tr)
results = model.fit()

results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.686324
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            loan_status   No. Observations:               686439
# Model:                          Logit   Df Residuals:                   686430
# Method:                           MLE   Df Model:                            8
# Date:                Wed, 21 Feb 2018   Pseudo R-squ.:                  -2.227
# Time:                        12:06:51   Log-Likelihood:            -4.7112e+05
# converged:                       True   LL-Null:                   -1.4600e+05
#                                         LLR p-value:                     1.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1858      0.003    -73.191      0.000      -0.191      -0.181
# x2             0.1178      0.003     40.595      0.000       0.112       0.123
# x3            -0.0007      0.003     -0.242      0.809      -0.006       0.005
# x4            -0.0184      0.003     -5.787      0.000      -0.025      -0.012
# x5             0.0119      0.006      1.985      0.047       0.000       0.024
# x6            -0.0013      0.003     -0.481      0.630      -0.006       0.004
# x7            -0.0063      0.003     -2.357      0.018      -0.012      -0.001
# x8            -0.0084      0.003     -2.833      0.005      -0.014      -0.003
# x9            -0.0091      0.002     -3.663      0.000      -0.014      -0.004
# ==============================================================================
# """

# %% [markdown]
# ## Logistic Regression with Cross Validation, Scaled Features, Balanced Class Weights

# %% [markdown]
# #### 1. Logistic Regression with Scaled Features, Cross Validation, and Balanced Class Weights

# %%
#Now I will do Logistic Regression with the scaled features + balanced class weights

logreg = LogisticRegressionCV(class_weight='balanced', cv = 5)
logreg.fit(X_tr, y_train)
# Out:
# LogisticRegressionCV(Cs=10, class_weight='balanced', cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#            refit=True, scoring=None, solver='lbfgs', tol=0.0001, verbose=0)

# %%
#Accuracy

y_pred = logreg.predict(X_te)
print(logreg.score(X_te, y_test))
# Out:
# 0.686999592098

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.68      0.80    162159
#           1       0.13      0.82      0.22      9451
#
# avg / total       0.94      0.69      0.77    171610

# %%
#Review coefficients
#Current, Fully Paid, Charged Off, Default
logreg.fit(X_te,y_test).coef_
# Out:
# array([[-1.41920518,  0.67360946,  0.01655382, -0.23538396,  0.30007155,
#         -0.06125467, -0.01067354, -0.05459407, -0.03622767]])

# %% [markdown]
# #### 2. Logistic Regression with Oversampling, Scaled Features, and Cross Validation - BEST MODEL

# %%
ROS = imblearn.over_sampling.RandomOverSampler(ratio=.4, random_state=42) 
    
X_tr_rs, y_tr_rs = ROS.fit_sample(X_tr, y_train)

logreg = LogisticRegressionCV(cv = 5)
logreg.fit(X_tr_rs, y_tr_rs)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# LogisticRegressionCV(Cs=10, class_weight=None, cv=5, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#            refit=True, scoring=None, solver='lbfgs', tol=0.0001, verbose=0)

# %%
y_pred = logreg.predict(X_te)
print(logreg.score(X_te, y_test))
# Out:
# 0.851914224113

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.87      0.92    162159
#           1       0.18      0.49      0.27      9451
#
# avg / total       0.92      0.85      0.88    171610

# %%
### Get Coefficients of Logistic Regression

# %%
logreg.fit(X_tr_rs, y_tr_rs).coef_
# Out:
# array([[-1.3771273 ,  0.62641685,  0.02261818, -0.24434999,  0.2223375 ,
#         -0.03563512, -0.02039958, -0.05335534, -0.00752965]])

# %%
list(zip(logreg.fit(X_tr_rs, y_tr_rs).coef_))
# Out:
# [(array([-1.3771273 ,  0.62641685,  0.02261818, -0.24434999,  0.2223375 ,
#          -0.03563512, -0.02039958, -0.05335534, -0.00752965]),)]

# %%
X_train.columns
# Out:
# Index(['member_id', 'int_rate', 'loan_amnt', 'annual_inc', 'dti', 'revol_util',
#        'total_acc', 'term', 'pub_rec'],
#       dtype='object')

# %%
logmodel = logreg.fit(X_tr_rs, y_tr_rs)

# %%
sorted(zip(X.columns,(logreg.fit(X_tr_rs, y_tr_rs)).coef_), key=lambda x: -x[1])
# Out:
# [('member_id',
#   array([-1.3771273 ,  0.62641685,  0.02261818, -0.24434999,  0.2223375 ,
#          -0.03563512, -0.02039958, -0.05335534, -0.00752965]))]

# %%
coeff_list = logmodel.coef_

# %%
coeff_list
# Out:
# array([[-1.3771273 ,  0.62641685,  0.02261818, -0.24434999,  0.2223375 ,
#         -0.03563512, -0.02039958, -0.05335534, -0.00752965]])

# %%
new_list = coeff_list.tolist()

# %%
new_list
# Out:
# [[-1.377127301656656,
#   0.6264168523911776,
#   0.02261817588115635,
#   -0.24434999216097403,
#   0.22233749642710762,
#   -0.035635116003272724,
#   -0.020399576880564985,
#   -0.0533553418490335,
#   -0.007529650512489875]]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('member_id', 'int_rate', 'loan_amnt', 'annual_inc', 'dti', 'revol_util',
       'total_acc', 'term', 'pub_rec')
y_pos = np.arange(len(objects))
performance = [-1.377127301656656, 0.6264168523911776, 0.02261817588115635,
  -0.24434999216097403,
  0.22233749642710762,
  -0.035635116003272724,
  -0.020399576880564985,
  -0.0533553418490335,
  -0.007529650512489875]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation='vertical')
plt.xlabel('Features')
plt.ylabel('Coefficients')
plt.title('Feature Coefficients')
plt.subplots_adjust(bottom=0.2)

# %% [markdown]
# X_tr = scaled training data
#
# X_tr_rs = oversampled scaled training data
#
# y_tr_rs = oversampled training data

# %% [markdown]
# ## F-1 Optimization on Oversampled Data

# %%
logreg = LogisticRegressionCV(cv = 5)

logreg.fit(X_tr_rs, y_tr_rs)




import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

X_val, y_val = X_te, y_test # explicitly calling this validation since we're using it for selection

thresh_ps = np.linspace(.10,.80,1000)
model_val_probs = logreg.predict_proba(X_val)[:,1] # positive class probs, same basic logistic model we fit in section 2 

f1_scores = []
for p in thresh_ps:
    model_val_labels = model_val_probs >= p
    f1_scores.append(f1_score(model_val_labels, y_val))
    
plt.plot(thresh_ps, f1_scores)
plt.title('F1 Score vs. Positive Class Decision Probability Threshold')
plt.xlabel('P threshold')
plt.ylabel('F1 score')

best_f1_score = np.max(f1_scores) 
best_thresh_p = thresh_ps[np.argmax(f1_scores)]

print('Logistic Regression Model best F1 score %.3f at prob decision threshold >= %.3f' 
      % (best_f1_score, best_thresh_p))
# Out:
# Logistic Regression Model best F1 score 0.269 at prob decision threshold >= 0.523

# %% [markdown]
# ## F1 on Imbalanced Data (Still Scaled)

# %%
logreg = LogisticRegressionCV(cv = 5)

logreg.fit(X_tr, y_train)




import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

X_val, y_val = X_te, y_test # explicitly calling this validation since we're using it for selection

thresh_ps = np.linspace(.10,.80,1000)
model_val_probs = logreg.predict_proba(X_val)[:,1] # positive class probs, same basic logistic model we fit in section 2 

f1_scores = []
for p in thresh_ps:
    model_val_labels = model_val_probs >= p
    f1_scores.append(f1_score(model_val_labels, y_val))
    
plt.plot(thresh_ps, f1_scores)
plt.title('F1 Score vs. Positive Class Decision Probability Threshold')
plt.xlabel('P threshold')
plt.ylabel('F1 score')

best_f1_score = np.max(f1_scores) 
best_thresh_p = thresh_ps[np.argmax(f1_scores)]

print('Logistic Regression Model best F1 score %.3f at prob decision threshold >= %.3f' 
      % (best_f1_score, best_thresh_p))
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# Logistic Regression Model best F1 score 0.270 at prob decision threshold >= 0.115

# %% [markdown]
# ### ROC Curve

# %%
from sklearn.metrics import roc_curve, auc

ROS = imblearn.over_sampling.RandomOverSampler(ratio=.4, random_state=42) 
    
X_tr_rs, y_tr_rs = ROS.fit_sample(X_tr, y_train)

logreg = LogisticRegressionCV(cv = 5)


logreg.fit(X_tr_rs,np.ravel(y_tr_rs))
y_score=logreg.predict_proba(X_te)[:,1]

fpr, tpr,_ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
# Plotting our Baseline..
plt.plot([0,1],[0,1])
plt.plot(fpr,tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function _ratio_float is deprecated; Use a float for 'ratio' is deprecated from version 0.2. The support will be removed in 0.4. Use a dict, str, or a callable instead.
#   warnings.warn(msg, category=DeprecationWarning)
# Text(0,0.5,'True Positive Rate')
